# %%
import pandas as pd

daily_df = pd.read_csv("data/daily_report.csv")

totals_df = (daily_df[["Confirmed", "Deaths", "Recovered"]].sum().reset_index(name="count"))

totals_df = totals_df.rename(columns={"index": "condition"})

countries_df = daily_df[["Country_Region", "Confirmed", "Deaths", "Recovered"]]
countries_df = countries_df.groupby("Country_Region").sum().reset_index()

countries_df
# Out:
#          Country_Region  Confirmed  Deaths  Recovered
# 0           Afghanistan      53938    2336      45465
# 1               Albania      67216    1270      40090
# 2               Algeria     103611    2831      70373
# 3               Andorra       9038      91       8116
# 4                Angola      18765     431      16225
# ..                  ...        ...     ...        ...
# 186             Vietnam       1537      35       1380
# 187  West Bank and Gaza     151569    1700     138495
# 188               Yemen       2112     612       1419
# 189              Zambia      36074     537      25106
# 190            Zimbabwe      26881     683      15872
#
# [191 rows x 4 columns]
